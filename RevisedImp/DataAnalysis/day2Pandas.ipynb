# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/netflix_titles.csv")
# pd.read_excel("", sheet_name=0) (xlsx)
# pd.read_excel("trns.xlsx", sheet_name="main")
# pd.read_json (json)


#----------------------HOW to Write in file-----
# df.to_csv("trns.csv", index=False)
# df.to_excel("trns.xlsx", sheet_name=0, index=False)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head(5) #top 5 data
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail(8) #this get bottom data
# Out:
#      show_id     type               title         director  \
# 8799   s8800    Movie               Zenda   Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai              NaN
# 8801   s8802    Movie             Zinzana  Majid Al Ansari
# 8802   s8803    Movie              Zodiac    David Fincher
# 8803   s8804  TV Show         Zombie Dumb              NaN
# 8804   s8805    Movie          Zombieland  Ruben Fleischer
# 8805   s8806    Movie                Zoom     Peter Hewitt
# 8806   s8807    Movie              Zubaan      Mozez Singh
#
#                                                    cast  \
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# ...

# %%
# Missing Values
df.isna() #check missing values
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.isnull()#same as isna
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
count = 0
if df['date_added'].isnull()[1] == False:
  count += 1
  print("This is True") #isna
print(count)
# Out:
# This is True
# 1

# %%
#Category Data / Qualitative Data
#Numerical / Quantitative Data

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.dtypes #shows every column dataTypes
#listn alwys qualitative data shown in Object
#And alwys quantitative data shown in int,float
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
date = df['date_added'][6079].strip() #this take date_added column
date
# Out:
# 'August 4, 2017'

# %%
from datetime import datetime
ans = datetime.strptime("April 15, 2021", "%B %d, %Y").strftime("%m/%d/%Y")
ans
# Out:
# '04/15/2021'

# %%
all_date = []
from datetime import datetime
for i in range(len(df['date_added'])):
  if df['date_added'].isnull()[i] == False or df['date_added'].isna()[i] == False:
    all_date.append(datetime.strptime(f"{df['date_added'][i].strip()}", "%B %d, %Y").strftime("%m/%d/%Y"))
  else:
    continue
date_series = pd.Series(all_date)
df['date_added'] = date_series #Data Format
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#above was the user defined thing done but dtype was object still
#but below function pd.to_datetime is always correct dateTime data type so, dtype:dateTime
df['date_added'] = pd.to_datetime(df['date_added'])

# %% [markdown]
# 2.Cleaninig null **value** **bold text**

# %%
df.dropna(inplace=True)#remove the missing vaue

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# **3.Fill na OR Null Value**

# %%
df = pd.read_csv("/content/netflix_titles.csv")
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
all_date = []
from datetime import datetime
for i in range(len(df['date_added'])):
  if df['date_added'].isnull()[i] == False or df['date_added'].isna()[i] == False:
    all_date.append(datetime.strptime(f"{df['date_added'][i].strip()}", "%B %d, %Y").strftime("%m/%d/%Y"))
  else:
    continue
date_series = pd.Series(all_date)
df['date_added'] = date_series
df['date_added'] = pd.to_datetime(df['date_added'])
#df["category"].fillna("-", inplace=True)

# %%
df['director'].fillna("-", inplace=True) #this convert na value into "-", but giving "-" was not good practice instead min,max,mean
df
# Out:
# /tmp/ipykernel_1433/1862052514.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna("-", inplace=True)
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water                -
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans                -
# 4         s5  TV Show           Kota Factory                -
# ...

# %%
df['duration'].isna().sum() #we are getting 3 na in duration
#so, now we are set those na into mean(average value)

df['duration'].fillna(mean(df['']))
# Out:
# np.int64(3)

# %%
# for i in range(len(df)):
#   if df['duration'].isna()[i] == False and df['duration'][1].split(" ")[1] == 'min':
#     print(df)
    #df['duration'][i] = pd.to_numeric(df['duration'][i])

# %%
len(df)
# Out:
# 8807

# %%
df['duration'][1].split(" ")[1]
# Out:
# 'Seasons'

# %%
df.duplicated().sum()#no duplicate Values
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
#df['amount'] = df['amount'].astype(int)#convert float to int

# %%
df.to_csv("filtered_transaction.csv", index=False)#if i'll put index=True then I'll get label value form 1 to len(data)
